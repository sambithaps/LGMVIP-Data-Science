# %% [markdown]
# # LETS GROW MORE-DATA SCIENCE
#
# ### AUTHOR: Sambitha P Santhosh
#
# ### OBJECTIVE: Image to Pencil Sketch with Python:

# %%
#pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\aby mathews\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("car.jpeg")
#cv2.imshow("CAR", image)
cv2.waitKey(0)
plt.imshow(image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#cv2.imshow("New Car", gray_image)
cv2.waitKey(0)
plt.imshow(gray_image,cmap='gray')

# %%
inverted_image = 255 - gray_image
#cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
plt.imshow(inverted_image,cmap='gray')

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
#cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
plt.imshow(pencil_sketch,cmap='gray')
